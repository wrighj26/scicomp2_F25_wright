# %% [markdown]
# # `Flax`
#
# You may have heard of `TensorFlow`, one of the first hugely popular libraries for computing data flow graphs -- operations which we've effectively been doing much of this class, and are the underpinning of neural networks.  `Flax` is effectively `TensorFlow` build on `JAX`, and will be our main library for constructing and training neural networks.
#
# If you don't already have it installed (e.g., using the codespace), you can install it with:
#
# ```bash
# !pip install -q flax
# ```

# %%
import jax
from jax import random, numpy as jnp
from flax import linen as nn

from numpy import genfromtxt
import matplotlib.pyplot as plt
# !pip install -q flax
# Out:
# /opt/conda/lib/python3.12/pty.py:95: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
#   WARNING: The scripts f2py and numpy-config are installed in '/home/wrighj26/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory '/home/wrighj26/.local/lib/python3.12/site-packages/~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/home/wrighj26/.local/lib/python3.12/site-packages/~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/home/wrighj26/.local/lib/python3.12/site-packages/~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/home/wrighj26/.local/lib/python3.12/site-packages/~cipy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nglview 0.0.0 requires notebook>=7, but you have notebook 6.5.7 which is incompatible.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.3.5 which is incompatible.

# %% [markdown]
# # Linear Regression as a Neural Network
#
# We'll repeat (again) our linear regression example, but this time using `Flax` perform linear regression using a single dense neural network layer.
#
# First let's read in the data.

# %%
data = genfromtxt('../data/data_yerr.dat', names=True, comments='#', delimiter='&')

train_X = jnp.array(data['x'])
train_Y = jnp.array(data['y'])

n_samples = train_X.shape[0]
plt.scatter(train_X, train_Y)
plt.xlabel('$x$')
plt.ylabel('$y$');

# %% [markdown]
# Let's reshape:

# %%
X = data['x'].reshape(-1, 1)
y = data['y'].reshape(-1, 1)
X_tst = jnp.linspace(X.min(), X.max(), 100).reshape(-1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 X = data['x'].reshape(-1, 1)
#       2 y = data['y'].reshape(-1, 1)
# ----> 3 X_tst = jnp.linspace(X.min(), X.max(), 100).reshape(-1, 1)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/numpy/array_creation.py:549, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     547 num = core.concrete_dim_or_error(num, "'num' argument of jnp.linspace")
#     548 axis = core.concrete_or_error(operator.index, axis, "'axis' argument of jnp.linspace")
# --> 549 return _linspace(start, stop, num, endpoint, retstep, dtype, axis, device=device)
#
#     [... skipping hidden 15 frame]
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/numpy/array_creation.py:577, in _linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     575 div = (num - 1) if endpoint else num
#     576 if num > 1:
# --> 577   delta: Array = lax.convert_element_type(stop - start, computation_dtype) / asarray(div, dtype=computation_dtype)
#     578   iota_shape = [1,] * len(bounds_shape)
#     579   iota_shape[axis] = div
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/numpy/array_constructors.py:399, in asarray(a, dtype, order, copy, device, out_sharding)
#     397 if dtype is not None:
#     398   dtype = dtypes.check_and_canonicalize_user_dtype(dtype, "asarray")
# --> 399 return array(a, dtype=dtype, copy=bool(copy), order=order, device=device,
#     400              out_sharding=out_sharding)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/numpy/array_constructors.py:284, in array(object, dtype, copy, order, ndmin, device, out_sharding)
#     282 else:
#     283   raise TypeError(f"Unexpected input type for array: {type(object)}")
# --> 284 out_array: Array = lax._convert_element_type(
#     285     out, dtype, weak_type=weak_type, sharding=sharding)
#     286 if ndmin > np.ndim(out_array):
#     287   out_array = lax.expand_dims(out_array, range(ndmin - np.ndim(out_array)))
#
#     [... skipping hidden 9 frame]
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/literals.py:161, in TypedNdArray.__array__(self, dtype, copy)
#     154 def __array__(self, dtype=None, copy=None):
#     155   # You might think that we can do the following here:
#     156   # return self.val.__array__(dtype=dtype, copy=copy)
#    (...)    159   # TODO(phawkins): revert to the above form once NumPy 2.3 is the minimum
#     160   # supported version.
# --> 161   return np.asarray(self.val, dtype=dtype, copy=copy)
#
# TypeError: asarray() got an unexpected keyword argument 'copy'

# %% [markdown]
# To replicate linear regression we just need a single dense layer with a single output.  We'll use the `flax.nn` module to define our model.

# %%
# We create one dense layer instance, where 'features' sets the output dimension
model = nn.Dense(features=1)

# %% [markdown]
# The models don't actually store the parameters, so we need to initialize them with the `init` method.  We'll use the `jax.random.PRNGKey` to seed the random number generator as we have before.

# %%
key1, key2 = random.split(random.PRNGKey(0)) # random keys
params = model.init(key2, X[0])       # provide an example input so it can infer the shapes
params
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 key1, key2 = random.split(random.PRNGKey(0)) # random keys
#       2 params = model.init(key2, X[0])       # provide an example input so it can infer the shapes
#       3 params
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/random.py:248, in PRNGKey(seed, impl)
#     222 def PRNGKey(seed: int | ArrayLike, *,
#     223             impl: PRNGSpecDesc | None = None) -> Array:
#     224   """Create a legacy PRNG key given an integer seed.
#     225
#     226   This function produces old-style legacy PRNG keys, which are arrays
#    (...)    246     and ``fold_in``.
#     247   """
# --> 248   return _return_prng_keys(True, _key('PRNGKey', seed, impl))
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/random.py:200, in _key(ctor_name, seed, impl_spec)
#     196 if np.ndim(seed):
#     197   raise TypeError(
#     198       f"{ctor_name} accepts a scalar seed, but was given an array of "
#     199       f"shape {np.shape(seed)} != (). Use jax.vmap for batching")
# --> 200 return prng.random_seed(seed, impl=impl)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/prng.py:559, in random_seed(seeds, impl)
#     557 if config.random_seed_offset.value:
#     558   seeds_arr += config.random_seed_offset.value
# --> 559 return random_seed_p.bind(seeds_arr, impl=impl)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     630 def bind(self, *args, **params):
#     631   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632   return self._true_bind(*args, **params)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/core.py:660, in Primitive.bind_with_trace(self, trace, args, params)
#     658     with set_current_trace(trace):
#     659       return self.to_lojax(*args, **params)  # type: ignore
# --> 660   return trace.process_primitive(self, args, params)
#     661 trace.process_primitive(self, args, params)  # may raise lojax error
#     662 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/prng.py:572, in random_seed_impl(seeds, impl)
#     570 @random_seed_p.def_impl
#     571 def random_seed_impl(seeds, *, impl):
# --> 572   base_arr = random_seed_impl_base(seeds, impl=impl)
#     573   return PRNGKeyArray(impl, base_arr)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/prng.py:577, in random_seed_impl_base(seeds, impl)
#     575 def random_seed_impl_base(seeds, *, impl):
#     576   seed = iterated_vmap_unary(np.ndim(seeds), impl.seed)
# --> 577   return seed(seeds)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/prng.py:814, in threefry_seed(seed)
#     802 def threefry_seed(seed: typing.Array) -> typing.Array:
#     803   """Create a single raw threefry PRNG key from an integer seed.
#     804
#     805   Args:
#    (...)    812     first padding out with zeros).
#     813   """
# --> 814   return _threefry_seed(seed)
#
#     [... skipping hidden 13 frame]
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/prng.py:828, in _threefry_seed(seed)
#     823 k1 = convert(
#     824     lax.shift_right_logical(seed, lax._const(seed, 32)))
#     825 with config.numpy_dtype_promotion('standard'):
#     826   # TODO(jakevdp): in X64 mode, this can generate 64-bit computations for 32-bit
#     827   # inputs. We should avoid this.
# --> 828   k2 = convert(jnp.bitwise_and(seed, np.uint32(0xFFFFFFFF)))
#     829 return lax.concatenate([k1, k2], 0)
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:183, in ufunc.__call__(self, out, where, *args)
#     181   raise NotImplementedError(f"where argument of {self}")
#     182 call = self.__static_props['call'] or self._call_vectorized
# --> 183 return call(*args)
#
#     [... skipping hidden 11 frame]
#
# File /home/.hub_local/python_libs/lib/python3.12/site-packages/jax/_src/literals.py:161, in TypedNdArray.__array__(self, dtype, copy)
#     154 def __array__(self, dtype=None, copy=None):
#     155   # You might think that we can do the following here:
#     156   # return self.val.__array__(dtype=dtype, copy=copy)
#    (...)    159   # TODO(phawkins): revert to the above form once NumPy 2.3 is the minimum
#     160   # supported version.
# --> 161   return np.asarray(self.val, dtype=dtype, copy=copy)
#
# TypeError: asarray() got an unexpected keyword argument 'copy'

# %% [markdown]
# We can see that `params` has a kernel (i.e., weights, or slope in this case) and bias (y-intercept), initialized to random and zero values, respectively.

# %% [markdown]
# If we want to compute a forward pass of our model (i.e., plug in a `x` value and get a predicted `y` value), we can use the `apply` method.  Remember the parameters (slope and y-intercept) aren't stored in the model, so we need to provide them.

# %%
model.apply(params,X[0]) # example application of the model
# Out:
# Array([424.66675], dtype=float32)

# %% [markdown]
# ## Cost Function
#
# Recall that performing linear regression is equivalent to minimizing the mean squared error (MSE) between the model predictions and the data.
#
# We're going to minimize the MSE using gradient descent, and we'll write everything from scratch as an excuse to learn how to use `Flax`.
#
# First the cost function.  We're going to have `JAX` do some optimization with just-in-time (JIT) compiling (see [here](https://jax.readthedocs.io/en/latest/notebooks/quickstart.html#using-jit-to-speed-up-functions) for gorier details).

# %%
@jax.jit
def mse(params, x_batched, y_batched):
    # the squared loss for a single (x, y) pair
    def squared_error(x, y):
        pred = model.apply(params, x)
        return jnp.inner(y - pred, y - pred)/2.0
    # vectorize this to compute the averae loss over a batch of data
    return jnp.mean(jax.vmap(squared_error)(x_batched, y_batched), axis=0)

# %%
mse(params, X, y)
# Out:
# Array(9112.817, dtype=float32)

# %%
# %timeit mse(params, X, y)
# Out:
# 6.39 μs ± 191 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# It works, and it's fast!  Try commenting out the `@jax.jit` decorator and rerun the two cells above to compare run times.
#
# ## Gradient Decent
#
# Recall the algorithm for gradient decent:
# $$
# \mathrm{repeat~until~convergence} \{\\
# \theta_j = \theta_j - \alpha \frac{\partial}{\partial\theta_j}J(\theta_0, \theta_1) \mathrm{~~~~for~}j=0\mathrm{~and~}j=1
# \\\}
# $$
#
# where $\alpha$ is the *learning rate*.
#
# Remember that one of `JAX`'s superpowers is that it can automatically compute gradients of functions.  `jax.value_and_grad()` will give us a function that computes the value and gradient of our MSE cost function for us.

# %%
loss_grad_fn = jax.value_and_grad(mse)
loss_grad_fn(params, X, y)
# Out:
# (Array(9112.818, dtype=float32),
#  FrozenDict({
#      params: {
#          bias: Array([-53.6239], dtype=float32),
#          kernel: Array([[-4828.3003]], dtype=float32),
#      },
#  }))

# %% [markdown]
# Let's use it to update parameters during gradient decent.

# %%
learning_rate = 0.00001 # Gradient descent step size

@jax.jit
def update_params(params, learning_rate, grads):
    params = jax.tree_util.tree_map(
        lambda p, g: p - learning_rate * g, params, grads)
    return params

# %% [markdown]
# ...and finally put it all together:

# %%
loss_vals = []
for step in range(100):
    loss_val, grads = loss_grad_fn(params, X, y)
    params = update_params(params, learning_rate, grads)
    if step % 10 == 0: # print every 10 steps
        print(f"Step {step}, loss {loss_val}")
    loss_vals.append(loss_val)
# Out:
# Step 0, loss 9112.818359375
# Step 10, loss 8759.513671875
# Step 20, loss 8759.3154296875
# Step 30, loss 8759.236328125
# Step 40, loss 8759.15625
# Step 50, loss 8759.076171875
# Step 60, loss 8758.9951171875
# Step 70, loss 8758.9169921875
# Step 80, loss 8758.8359375
# Step 90, loss 8758.755859375

# %%
plt.plot(loss_vals);

# %%
plt.scatter(X, y)
plt.plot(X_tst, model.apply(params, X_tst));

# %% [markdown]
# ## Fancier Optimization

# %%
import optax
tx = optax.adam(learning_rate=learning_rate)
opt_state = tx.init(params)
loss_grad_fn = jax.value_and_grad(mse)

# %%
for i in range(101):
  loss_val, grads = loss_grad_fn(params, X, y)
  updates, opt_state = tx.update(grads, opt_state)
  params = optax.apply_updates(params, updates)
  if i % 10 == 0:
    print('Loss step {}: '.format(i), loss_val)
# Out:
# Loss step 0:  8758.676
# Loss step 10:  8758.673
# Loss step 20:  8758.671
# Loss step 30:  8758.668
# Loss step 40:  8758.664
# Loss step 50:  8758.662
# Loss step 60:  8758.659
# Loss step 70:  8758.656
# Loss step 80:  8758.652
# Loss step 90:  8758.651
# Loss step 100:  8758.647
