# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/births/US_births_2000-2014_SSA.csv')
df
# Out:
#       year  month  date_of_month  day_of_week  births
# 0     2000      1              1            6    9083
# 1     2000      1              2            7    8006
# 2     2000      1              3            1   11363
# 3     2000      1              4            2   13032
# 4     2000      1              5            3   12558
# ...    ...    ...            ...          ...     ...
# 5474  2014     12             27            6    8656
# 5475  2014     12             28            7    7724
# 5476  2014     12             29            1   12811
# 5477  2014     12             30            2   13634
# 5478  2014     12             31            3   11990
#
# [5479 rows x 5 columns]

# %%
grp = df.groupby('month')
months=grp.mean()
plt.plot(months.index, months.births)

# %%
plt.plot(birth_by_date.index, birth_by_date.births)
plt.xlabel('date of month')
plt.ylabel('avg. births per day');

# %%
plt.plot(christmas_date_birth_by_month.index, christmas_date_birth_by_month.births)
plt.xlabel('month')
plt.ylabel('avg. births per day')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.plot(christmas_date_birth_by_month.index, christmas_date_birth_by_month.births)
#       2 plt.xlabel('month')
#       3 plt.ylabel('avg. births per day')
#
# NameError: name 'christmas_date_birth_by_month' is not defined
